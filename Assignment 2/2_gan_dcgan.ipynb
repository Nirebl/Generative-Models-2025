# %% [markdown]
# <a href="https://colab.research.google.com/github/RostislavKorst/Generative-Models-2025/blob/main/Assignment%202/2_gan_dcgan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generative Models
# ***
#
# **Autumn 2025, MSc course**

# %% [markdown]
# ## Assignment 2
#
# ***
#
#
# *Authored by Arip Asadulaev & Manh Lab*
#
# *Adapted by Alexander Panfilov*
#
# ***

# %% [markdown]
# The assignment is split into two parts: at first, you will implement classical GAN for the MNIST dataset, and after, you will enhance your results with DCGAN and the CIFAR dataset.
#
# Good luck!

# %% [markdown]
# ## 1. GAN
# *Source: <a href="https://arxiv.org/pdf/1406.2661.pdf" target="_blank">Goodfellow, Ian J., et al. "Generative Adversarial Networks." arXiv preprint arXiv:1406.2661 (2014)</a>.*

# %% [markdown]
# In 2014, Ian Goodfellow and his colleagues at the University of Montreal published a stunning paper introducing the world to GANs, or generative adversarial networks. The models play two distinct (literally, adversarial) roles. Given some real data set $\mathcal{X}$, $G$ is the generator, trying to create fake data that looks just like the genuine data, while $D$ is the discriminator, getting data from either the real set or $G$ and labeling the difference.
#
# Goodfellow’s metaphor (and a fine one it is) was that $G$ was like a team of forgers trying to match real paintings with their output, while $D$ was the team of detectives trying to tell the difference. (Except in this case, the forgers $G$ never get to see the original data — only the judgments of $D$. They’re like blind forgers.)
#
# <img src="https://production-media.paperswithcode.com/methods/gan.jpeg" style="display=block; margin:auto"/>
# <p style="text-align: center">
#     <b>Picture taken from the <a href="https://paperswithcode.com/method/gan" target="_blank">paperswithcode</a> website. There you can find a whole bunch of papers on GANs with implementation.</b>
# </p>

# %% [markdown]
# In this part, we are going to implement classical GAN. You can find a rough plan on how to do it below; however, it is not mandatory to stick with it precisely but one might expect some questions related to the listed steps. Feel free to adapt provided code!
#
# - Define the parameters
# - Load the data (with transforms and normalization)
# - Denormalize for visual inspection of samples
# - Define the Discriminator network, the Generator network
# - Study the activation function: Leaky ReLU
# - Explain the output activation function: Tanh, Sigmoid
# - Look at some sample outputs
# - Define losses, optimizers and helper functions for training
#      - For Discriminator
#      - For Generator
# - Train the model
# - Save intermediate generated images to file
# - Look at some outputs
# - Save the models

# %% [markdown]
# ### Imports

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torchvision import transforms
from torchvision.datasets import CIFAR10, MNIST
from torchvision.transforms import Compose, Normalize, ToTensor
from torchvision.utils import save_image

# %matplotlib inline
plt.style.use("ggplot")

# %% [markdown]
# ### Define parameters & data loading

# %%
hidden_size = 256
batch_size = 100
LR = 0.0002
num_epochs = 300
sample_dir = "./images"
latent_size = 64  # input random input vector latent
image_size = 784  # 28*28 flatten
device = "cuda" if torch.cuda.is_available() else "cpu"

if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)
## Define the dataset
mnist_dataset = MNIST(
    root="data",
    train=True,
    download=True,
    transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]),
)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
img, label = mnist_dataset[0]
print("Label: ", label)
plt.hist(img[:, 5:15, 5:15].flatten(), bins=15)
# Out:
# Label:  5
# (array([55.,  4.,  3.,  0.,  3.,  2.,  1.,  0.,  1.,  3.,  1.,  3.,  2.,
#          1., 21.]),
#  array([-1.        , -0.86771244, -0.73542488, -0.60313725, -0.47084969,
#         -0.33856213, -0.20627451, -0.07398695,  0.05830061,  0.19058824,
#          0.32287574,  0.45516336,  0.58745098,  0.71973848,  0.8520261 ,
#          0.98431373]),
#  <BarContainer object of 15 artists>)

# %%
# denormalization image from range (-1)-1 to range 0-1 to display it
def denorm(x):
    return (x + 1) / 2

# %%
# show image sample with matplotlib
img, label = mnist_dataset[0]
plt.figure(figsize=(4, 4))
plt.imshow(denorm(img).squeeze(), cmap='gray')
plt.title(f'Label: {label}')
plt.axis('off')
plt.show()

# %%
# define the dataloader
data_loader = torch.utils.data.DataLoader(
    dataset=mnist_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True
)

# %% [markdown]
# ### GAN implementation

# %% [markdown]
# GAN consists of two deep networks, a generator ($G$) and a discriminator ($D$). The generator creates images before learning it. Since the discriminator is a binary classification model, we can use the binary cross-entropy loss function to quantify how well it can distinguish between real and generated images.

# %%
class Generator(nn.Module):
    def __init__(self, latent_size, image_size, hidden_size):
        super(Generator, self).__init__()
        # set a linear layer with input size is latent_size and output size is hidden_size
        self.linear1 = nn.Linear(latent_size, hidden_size)
        # set a linear layer with input size is hidden_size and output size is hidden_size
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        # set a linear layer with input size is hidden_size and output size is image_size
        self.linear3 = nn.Linear(hidden_size, image_size)

    def forward(self, x):
        # forward x -> linear1 -> relu -> linear2 -> relu -> linear3 -> tanh
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        x = torch.tanh(self.linear3(x))
        return x


class Discriminator(nn.Module):
    def __init__(self, image_size, hidden_size):
        super(Discriminator, self).__init__()
        # set a linear layer with input size is image_size and output size is hidden_size
        self.linear1 = nn.Linear(image_size, hidden_size)
        # set a linear layer with input size is hidden_size and output size is hidden_size
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        # set a linear layer with input size is hidden_size and output size is 1
        self.linear3 = nn.Linear(hidden_size, 1)

    def forward(self, x):
        # forward x -> linear1 -> relu -> linear2 -> relu -> linear3 -> sigmoid
        x = F.leaky_relu(self.linear1(x), 0.2)
        x = F.leaky_relu(self.linear2(x), 0.2)
        x = torch.sigmoid(self.linear3(x))
        return x

# %% [markdown]
# ### Create the Generator and Discriminator

# %%
# create new Generator model
G = Generator(latent_size, image_size, hidden_size)

# create new Discriminator model
D = Discriminator(image_size, hidden_size)

print("Generator:", G)
print("\nDiscriminator:", D)
# Out:
# Generator: Generator(
#   (linear1): Linear(in_features=64, out_features=256, bias=True)
#   (linear2): Linear(in_features=256, out_features=256, bias=True)
#   (linear3): Linear(in_features=256, out_features=784, bias=True)
# )
#
# Discriminator: Discriminator(
#   (linear1): Linear(in_features=784, out_features=256, bias=True)
#   (linear2): Linear(in_features=256, out_features=256, bias=True)
#   (linear3): Linear(in_features=256, out_features=1, bias=True)
# )

# %%
# show the output of model
y = G(torch.randn(2, latent_size))

# %%
# define the criterion is nn.BCELoss()
criterion = nn.BCELoss()

# Define the optimizer for generator and discriminator
d_optimizer = torch.optim.Adam(D.parameters(), lr=LR, betas=(0.5, 0.999))
g_optimizer = torch.optim.Adam(G.parameters(), lr=LR, betas=(0.5, 0.999))

# %% [markdown]
# Discriminator Training

# %%
def reset_grad():
    # reset gradient for optimizer of generator and discriminator
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()


def train_discriminator(D_model, G_model, images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D_model(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G_model(z)
    outputs = D_model(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Sum losses
    d_loss = d_loss_real + d_loss_fake

    # Reset gradients
    reset_grad()

    # Compute gradients
    d_loss.backward()

    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# Generator Training

# %%
def train_generator(G_model):
    # Generate fake images and calculate loss
    z = torch.Tensor(np.random.normal(0, 1, (batch_size, latent_size))).to(device)
    fake_images = G_model(z)
    labels = torch.ones(batch_size, 1).to(device)
    
    # calculate the generator loss
    outputs = D(fake_images)
    g_loss = criterion(outputs, labels)

    # Reset gradients
    reset_grad()

    # Backprop and optimize
    g_loss.backward()
    g_optimizer.step()

    return g_loss, fake_images

# %% [markdown]
# ### Start the training proccess

# %%
# function to save the sample output of generator
def save_fake_images_mnist(G_model, index):
    # sample_vectors = torch.randn(batch_size, latent_size).to(device)
    sample_vectors = torch.Tensor(np.random.normal(0, 1, (batch_size, latent_size))).to(
        device
    )
    fake_images = G_model(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = "fake_images-{0:0=4d}.png".format(index)
    print("Saving", fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# %%
# %%time
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []
G.to(device)
D.to(device)
for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator
        d_loss, real_score, fake_score = train_discriminator(D, G, images)

        # Train the generator
        g_loss, fake_images = train_generator(G)

        # Inspect the losses
        if (i + 1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print(
                "Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}".format(
                    epoch,
                    num_epochs,
                    i + 1,
                    total_step,
                    d_loss.item(),
                    g_loss.item(),
                    real_score.mean().item(),
                    fake_score.mean().item(),
                )
            )
    # Sample and save images
    save_fake_images_mnist(G, epoch + 1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 1.1104, g_loss: 0.9135, D(x): 0.55, D(G(z)): 0.40
# Epoch [0/300], Step [400/600], d_loss: 0.6338, g_loss: 1.8384, D(x): 0.88, D(G(z)): 0.39
# Epoch [0/300], Step [600/600], d_loss: 0.5101, g_loss: 2.8035, D(x): 0.90, D(G(z)): 0.32
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.4346, g_loss: 3.2629, D(x): 0.93, D(G(z)): 0.28
# Epoch [1/300], Step [400/600], d_loss: 0.3742, g_loss: 2.5044, D(x): 0.82, D(G(z)): 0.08
# Epoch [1/300], Step [600/600], d_loss: 0.3964, g_loss: 2.6145, D(x): 0.91, D(G(z)): 0.24
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.2463, g_loss: 3.2125, D(x): 0.89, D(G(z)): 0.08
# Epoch [2/300], Step [400/600], d_loss: 0.2354, g_loss: 2.8511, D(x): 0.91, D(G(z)): 0.09
# Epoch [2/300], Step [600/600], d_loss: 0.4938, g_loss: 1.7280, D(x): 0.76, D(G(z)): 0.07
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.1849, g_loss: 4.0728, D(x): 0.89, D(G(z)): 0.03
# Epoch [3/300], Step [400/600], d_loss: 0.2876, g_loss: 3.2126, D(x): 0.89, D(G(z)): 0.11
# Epoch [3/300], Step [600/600], d_loss: 0.2140, g_loss: 2.8220, D(x): 0.86, D(G(z)): 0.01
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.2006, g_loss: 3.4005, D(x): 0.93, D(G(z)): 0.09
# Epoch [4/300], Step [400/600], d_loss: 0.1595, g_loss: 3.9938, D(x): 0.93, D(G(z)): 0.05
# Epoch [4/300], Step [600/600], d_loss: 0.2415, g_loss: 3.6454, D(x): 0.91, D(G(z)): 0.09
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.2619, g_loss: 2.8199, D(x): 0.91, D(G(z)): 0.13
# Epoch [5/300], Step [400/600], d_loss: 0.5209, g_loss: 6.4501, D(x): 0.97, D(G(z)): 0.34
# Epoch [5/300], Step [600/600], d_loss: 0.1867, g_loss: 1.5467, D(x): 0.91, D(G(z)): 0.05
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.1408, g_loss: 3.7836, D(x): 0.93, D(G(z)): 0.05
# Epoch [6/300], Step [400/600], d_loss: 0.4081, g_loss: 2.2698, D(x): 0.82, D(G(z)): 0.05
# Epoch [6/300], Step [600/600], d_loss: 0.3221, g_loss: 2.2578, D(x): 0.85, D(G(z)): 0.05
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.1875, g_loss: 3.7194, D(x): 0.93, D(G(z)): 0.08
# Epoch [7/300], Step [400/600], d_loss: 0.2751, g_loss: 3.0504, D(x): 0.89, D(G(z)): 0.07
# Epoch [7/300], Step [600/600], d_loss: 0.2078, g_loss: 3.1762, D(x): 0.91, D(G(z)): 0.04
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1429, g_loss: 3.7452, D(x): 0.97, D(G(z)): 0.09
# Epoch [8/300], Step [400/600], d_loss: 0.2210, g_loss: 4.0944, D(x): 0.95, D(G(z)): 0.13
# Epoch [8/300], Step [600/600], d_loss: 0.1357, g_loss: 4.2836, D(x): 0.93, D(G(z)): 0.01
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.3147, g_loss: 3.1009, D(x): 0.92, D(G(z)): 0.14
# Epoch [9/300], Step [400/600], d_loss: 0.2219, g_loss: 3.1751, D(x): 0.92, D(G(z)): 0.08
# Epoch [9/300], Step [600/600], d_loss: 0.2621, g_loss: 2.6558, D(x): 0.89, D(G(z)): 0.05
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.4442, g_loss: 4.1596, D(x): 0.83, D(G(z)): 0.01
# Epoch [10/300], Step [400/600], d_loss: 0.5953, g_loss: 6.8101, D(x): 0.95, D(G(z)): 0.36
# Epoch [10/300], Step [600/600], d_loss: 0.2714, g_loss: 1.6354, D(x): 0.88, D(G(z)): 0.05
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.2474, g_loss: 2.4842, D(x): 0.88, D(G(z)): 0.05
# Epoch [11/300], Step [400/600], d_loss: 0.6173, g_loss: 2.2104, D(x): 0.91, D(G(z)): 0.33
# Epoch [11/300], Step [600/600], d_loss: 0.5357, g_loss: 1.9632, D(x): 0.83, D(G(z)): 0.17
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.3770, g_loss: 3.3822, D(x): 0.96, D(G(z)): 0.23
# Epoch [12/300], Step [400/600], d_loss: 0.3621, g_loss: 2.7004, D(x): 0.91, D(G(z)): 0.15
# Epoch [12/300], Step [600/600], d_loss: 0.5180, g_loss: 1.9349, D(x): 0.77, D(G(z)): 0.05
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.2696, g_loss: 2.7122, D(x): 0.90, D(G(z)): 0.08
# Epoch [13/300], Step [400/600], d_loss: 0.6502, g_loss: 2.1452, D(x): 0.86, D(G(z)): 0.30
# Epoch [13/300], Step [600/600], d_loss: 0.3880, g_loss: 3.8810, D(x): 0.90, D(G(z)): 0.18
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.5668, g_loss: 1.9133, D(x): 0.77, D(G(z)): 0.06
# Epoch [14/300], Step [400/600], d_loss: 0.5332, g_loss: 5.0957, D(x): 0.95, D(G(z)): 0.31
# Epoch [14/300], Step [600/600], d_loss: 0.2290, g_loss: 2.9053, D(x): 0.87, D(G(z)): 0.05
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.5240, g_loss: 4.8402, D(x): 0.95, D(G(z)): 0.32
# Epoch [15/300], Step [400/600], d_loss: 0.3759, g_loss: 3.3775, D(x): 0.90, D(G(z)): 0.20
# Epoch [15/300], Step [600/600], d_loss: 0.7059, g_loss: 1.3465, D(x): 0.70, D(G(z)): 0.04
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.4799, g_loss: 3.3959, D(x): 0.91, D(G(z)): 0.26
# Epoch [16/300], Step [400/600], d_loss: 0.3557, g_loss: 3.3362, D(x): 0.89, D(G(z)): 0.15
# Epoch [16/300], Step [600/600], d_loss: 0.5209, g_loss: 2.3612, D(x): 0.77, D(G(z)): 0.12
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.4289, g_loss: 2.3906, D(x): 0.81, D(G(z)): 0.12
# Epoch [17/300], Step [400/600], d_loss: 0.3242, g_loss: 2.4887, D(x): 0.88, D(G(z)): 0.14
# Epoch [17/300], Step [600/600], d_loss: 1.0478, g_loss: 5.4193, D(x): 0.92, D(G(z)): 0.54
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.5239, g_loss: 2.3573, D(x): 0.83, D(G(z)): 0.18
# Epoch [18/300], Step [400/600], d_loss: 0.4504, g_loss: 3.3665, D(x): 0.91, D(G(z)): 0.24
# Epoch [18/300], Step [600/600], d_loss: 0.6999, g_loss: 2.6196, D(x): 0.84, D(G(z)): 0.31
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 1.0595, g_loss: 3.4560, D(x): 0.85, D(G(z)): 0.51
# Epoch [19/300], Step [400/600], d_loss: 0.4282, g_loss: 2.6017, D(x): 0.81, D(G(z)): 0.07
# Epoch [19/300], Step [600/600], d_loss: 0.4782, g_loss: 1.8935, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.7229, g_loss: 1.4703, D(x): 0.73, D(G(z)): 0.18
# Epoch [20/300], Step [400/600], d_loss: 0.5981, g_loss: 1.5680, D(x): 0.71, D(G(z)): 0.07
# Epoch [20/300], Step [600/600], d_loss: 0.6508, g_loss: 2.3816, D(x): 0.79, D(G(z)): 0.19
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.4693, g_loss: 3.3265, D(x): 0.93, D(G(z)): 0.30
# Epoch [21/300], Step [400/600], d_loss: 0.5493, g_loss: 2.2194, D(x): 0.84, D(G(z)): 0.25
# Epoch [21/300], Step [600/600], d_loss: 0.5687, g_loss: 1.2984, D(x): 0.73, D(G(z)): 0.10
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.6593, g_loss: 1.8388, D(x): 0.76, D(G(z)): 0.21
# Epoch [22/300], Step [400/600], d_loss: 0.4134, g_loss: 2.2805, D(x): 0.81, D(G(z)): 0.12
# Epoch [22/300], Step [600/600], d_loss: 0.7950, g_loss: 2.1553, D(x): 0.79, D(G(z)): 0.31
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.7428, g_loss: 1.6464, D(x): 0.66, D(G(z)): 0.09
# Epoch [23/300], Step [400/600], d_loss: 0.8108, g_loss: 2.4194, D(x): 0.80, D(G(z)): 0.36
# Epoch [23/300], Step [600/600], d_loss: 1.0746, g_loss: 1.2065, D(x): 0.54, D(G(z)): 0.04
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.5075, g_loss: 1.7391, D(x): 0.80, D(G(z)): 0.17
# Epoch [24/300], Step [400/600], d_loss: 1.1141, g_loss: 2.8094, D(x): 0.86, D(G(z)): 0.54
# Epoch [24/300], Step [600/600], d_loss: 0.5988, g_loss: 2.5214, D(x): 0.85, D(G(z)): 0.29
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.6490, g_loss: 2.0485, D(x): 0.82, D(G(z)): 0.27
# Epoch [25/300], Step [400/600], d_loss: 0.8212, g_loss: 2.1008, D(x): 0.81, D(G(z)): 0.38
# Epoch [25/300], Step [600/600], d_loss: 0.7647, g_loss: 1.7882, D(x): 0.75, D(G(z)): 0.29
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.9274, g_loss: 1.5853, D(x): 0.79, D(G(z)): 0.40
# Epoch [26/300], Step [400/600], d_loss: 0.7189, g_loss: 1.2949, D(x): 0.72, D(G(z)): 0.23
# Epoch [26/300], Step [600/600], d_loss: 0.8906, g_loss: 0.9229, D(x): 0.57, D(G(z)): 0.11
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.6463, g_loss: 2.0496, D(x): 0.79, D(G(z)): 0.27
# Epoch [27/300], Step [400/600], d_loss: 0.7262, g_loss: 1.3542, D(x): 0.71, D(G(z)): 0.20
# Epoch [27/300], Step [600/600], d_loss: 0.9748, g_loss: 2.9738, D(x): 0.90, D(G(z)): 0.54
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.7714, g_loss: 1.3519, D(x): 0.66, D(G(z)): 0.17
# Epoch [28/300], Step [400/600], d_loss: 0.6419, g_loss: 1.4942, D(x): 0.73, D(G(z)): 0.18
# Epoch [28/300], Step [600/600], d_loss: 1.1946, g_loss: 0.8966, D(x): 0.54, D(G(z)): 0.23
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.6921, g_loss: 1.1937, D(x): 0.65, D(G(z)): 0.12
# Epoch [29/300], Step [400/600], d_loss: 0.9045, g_loss: 2.5539, D(x): 0.85, D(G(z)): 0.45
# Epoch [29/300], Step [600/600], d_loss: 0.6536, g_loss: 1.5460, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.8110, g_loss: 2.6311, D(x): 0.83, D(G(z)): 0.38
# Epoch [30/300], Step [400/600], d_loss: 1.0274, g_loss: 2.0276, D(x): 0.84, D(G(z)): 0.48
# Epoch [30/300], Step [600/600], d_loss: 0.5496, g_loss: 2.0588, D(x): 0.73, D(G(z)): 0.12
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.5196, g_loss: 1.8022, D(x): 0.79, D(G(z)): 0.18
# Epoch [31/300], Step [400/600], d_loss: 0.4628, g_loss: 1.9987, D(x): 0.82, D(G(z)): 0.18
# Epoch [31/300], Step [600/600], d_loss: 1.7480, g_loss: 1.2631, D(x): 0.37, D(G(z)): 0.04
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.7517, g_loss: 1.8188, D(x): 0.80, D(G(z)): 0.33
# Epoch [32/300], Step [400/600], d_loss: 0.8902, g_loss: 2.7692, D(x): 0.86, D(G(z)): 0.47
# Epoch [32/300], Step [600/600], d_loss: 1.0113, g_loss: 2.2064, D(x): 0.82, D(G(z)): 0.50
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.8223, g_loss: 1.2932, D(x): 0.65, D(G(z)): 0.21
# Epoch [33/300], Step [400/600], d_loss: 0.8236, g_loss: 0.9535, D(x): 0.59, D(G(z)): 0.11
# Epoch [33/300], Step [600/600], d_loss: 0.8635, g_loss: 2.1724, D(x): 0.80, D(G(z)): 0.39
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.7545, g_loss: 1.4131, D(x): 0.68, D(G(z)): 0.20
# Epoch [34/300], Step [400/600], d_loss: 0.9222, g_loss: 0.9349, D(x): 0.59, D(G(z)): 0.16
# Epoch [34/300], Step [600/600], d_loss: 0.8116, g_loss: 1.3729, D(x): 0.62, D(G(z)): 0.13
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.8556, g_loss: 1.7210, D(x): 0.74, D(G(z)): 0.32
# Epoch [35/300], Step [400/600], d_loss: 0.8777, g_loss: 1.2356, D(x): 0.68, D(G(z)): 0.28
# Epoch [35/300], Step [600/600], d_loss: 0.8386, g_loss: 2.9662, D(x): 0.85, D(G(z)): 0.42
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.8117, g_loss: 1.7194, D(x): 0.75, D(G(z)): 0.33
# Epoch [36/300], Step [400/600], d_loss: 1.0284, g_loss: 2.2176, D(x): 0.78, D(G(z)): 0.47
# Epoch [36/300], Step [600/600], d_loss: 1.1192, g_loss: 3.2996, D(x): 0.89, D(G(z)): 0.55
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.7518, g_loss: 1.8097, D(x): 0.77, D(G(z)): 0.30
# Epoch [37/300], Step [400/600], d_loss: 0.8229, g_loss: 1.9230, D(x): 0.82, D(G(z)): 0.39
# Epoch [37/300], Step [600/600], d_loss: 0.7527, g_loss: 1.7276, D(x): 0.79, D(G(z)): 0.33
# Saving fake_images-0038.png
# Epoch [181/300], Step [200/600], d_loss: 0.5853, g_loss: 2.6935, D(x): 0.83, D(G(z)): 0.21
# Epoch [181/300], Step [400/600], d_loss: 0.6734, g_loss: 1.5007, D(x): 0.76, D(G(z)): 0.15
# Epoch [181/300], Step [600/600], d_loss: 0.7680, g_loss: 2.6804, D(x): 0.82, D(G(z)): 0.27
# Saving fake_images-0182.png
# Epoch [182/300], Step [200/600], d_loss: 0.7255, g_loss: 2.1357, D(x): 0.85, D(G(z)): 0.33
# Epoch [182/300], Step [400/600], d_loss: 0.7154, g_loss: 2.1313, D(x): 0.81, D(G(z)): 0.28
# Epoch [182/300], Step [600/600], d_loss: 0.8306, g_loss: 2.2452, D(x): 0.81, D(G(z)): 0.34
# Saving fake_images-0183.png
# Epoch [183/300], Step [200/600], d_loss: 0.7211, g_loss: 1.5557, D(x): 0.73, D(G(z)): 0.14
# Epoch [183/300], Step [400/600], d_loss: 0.5198, g_loss: 1.9635, D(x): 0.83, D(G(z)): 0.16
# Epoch [183/300], Step [600/600], d_loss: 0.4728, g_loss: 1.8805, D(x): 0.85, D(G(z)): 0.15
# Saving fake_images-0184.png
# Epoch [184/300], Step [200/600], d_loss: 0.6142, g_loss: 2.3885, D(x): 0.83, D(G(z)): 0.24
# Epoch [184/300], Step [400/600], d_loss: 0.6732, g_loss: 1.9130, D(x): 0.81, D(G(z)): 0.23
# Epoch [184/300], Step [600/600], d_loss: 0.5647, g_loss: 1.9673, D(x): 0.85, D(G(z)): 0.22
# Saving fake_images-0185.png
# Epoch [185/300], Step [200/600], d_loss: 0.6045, g_loss: 2.1519, D(x): 0.86, D(G(z)): 0.26
# Epoch [185/300], Step [400/600], d_loss: 0.7056, g_loss: 2.1425, D(x): 0.84, D(G(z)): 0.27
# Epoch [185/300], Step [600/600], d_loss: 0.6268, g_loss: 2.0753, D(x): 0.82, D(G(z)): 0.20
# Saving fake_images-0186.png
# Epoch [186/300], Step [200/600], d_loss: 0.5743, g_loss: 2.3220, D(x): 0.85, D(G(z)): 0.22
# Epoch [186/300], Step [400/600], d_loss: 0.6280, g_loss: 1.5589, D(x): 0.80, D(G(z)): 0.19
# Epoch [186/300], Step [600/600], d_loss: 0.6119, g_loss: 2.0747, D(x): 0.79, D(G(z)): 0.18
# Saving fake_images-0187.png
# Epoch [187/300], Step [200/600], d_loss: 0.4079, g_loss: 1.9510, D(x): 0.87, D(G(z)): 0.14
# Epoch [187/300], Step [400/600], d_loss: 0.6554, g_loss: 2.1810, D(x): 0.79, D(G(z)): 0.18
# Epoch [187/300], Step [600/600], d_loss: 0.4969, g_loss: 1.8144, D(x): 0.85, D(G(z)): 0.22
# Saving fake_images-0188.png
# Epoch [188/300], Step [200/600], d_loss: 0.5890, g_loss: 1.8447, D(x): 0.78, D(G(z)): 0.15
# Epoch [188/300], Step [400/600], d_loss: 0.5245, g_loss: 1.8972, D(x): 0.81, D(G(z)): 0.14
# Epoch [188/300], Step [600/600], d_loss: 0.7000, g_loss: 2.0756, D(x): 0.77, D(G(z)): 0.19
# Saving fake_images-0189.png
# Epoch [189/300], Step [200/600], d_loss: 0.5067, g_loss: 2.3650, D(x): 0.84, D(G(z)): 0.17
# Epoch [189/300], Step [400/600], d_loss: 0.6727, g_loss: 1.9098, D(x): 0.75, D(G(z)): 0.16
# Epoch [189/300], Step [600/600], d_loss: 0.5237, g_loss: 2.0693, D(x): 0.86, D(G(z)): 0.19
# Saving fake_images-0190.png
# Epoch [190/300], Step [200/600], d_loss: 0.5982, g_loss: 2.7438, D(x): 0.84, D(G(z)): 0.23
# Epoch [190/300], Step [400/600], d_loss: 0.6328, g_loss: 2.1236, D(x): 0.86, D(G(z)): 0.27
# Epoch [190/300], Step [600/600], d_loss: 0.4628, g_loss: 2.4877, D(x): 0.86, D(G(z)): 0.17
# Saving fake_images-0191.png
# Epoch [191/300], Step [200/600], d_loss: 0.5635, g_loss: 2.1690, D(x): 0.79, D(G(z)): 0.14
# Epoch [191/300], Step [400/600], d_loss: 0.5631, g_loss: 1.9272, D(x): 0.83, D(G(z)): 0.17
# Epoch [191/300], Step [600/600], d_loss: 0.6621, g_loss: 1.9699, D(x): 0.82, D(G(z)): 0.25
# Saving fake_images-0192.png
# Epoch [192/300], Step [200/600], d_loss: 0.5925, g_loss: 2.0378, D(x): 0.82, D(G(z)): 0.20
# Epoch [192/300], Step [400/600], d_loss: 0.7304, g_loss: 1.8920, D(x): 0.73, D(G(z)): 0.13
# Epoch [192/300], Step [600/600], d_loss: 0.6343, g_loss: 2.0656, D(x): 0.82, D(G(z)): 0.22
# Saving fake_images-0193.png
# Epoch [193/300], Step [200/600], d_loss: 0.5404, g_loss: 1.8982, D(x): 0.85, D(G(z)): 0.21
# Epoch [193/300], Step [400/600], d_loss: 0.6290, g_loss: 2.0217, D(x): 0.80, D(G(z)): 0.19
# Epoch [193/300], Step [600/600], d_loss: 0.6318, g_loss: 1.7737, D(x): 0.76, D(G(z)): 0.17
# Saving fake_images-0194.png
# Epoch [194/300], Step [200/600], d_loss: 0.6538, g_loss: 2.1995, D(x): 0.80, D(G(z)): 0.20
# Epoch [194/300], Step [400/600], d_loss: 0.5521, g_loss: 2.0491, D(x): 0.82, D(G(z)): 0.20
# Epoch [194/300], Step [600/600], d_loss: 0.6735, g_loss: 2.2262, D(x): 0.81, D(G(z)): 0.25
# Saving fake_images-0195.png
# Epoch [195/300], Step [200/600], d_loss: 0.5851, g_loss: 1.9340, D(x): 0.82, D(G(z)): 0.22
# Epoch [195/300], Step [400/600], d_loss: 0.6743, g_loss: 2.0376, D(x): 0.80, D(G(z)): 0.26
# Epoch [195/300], Step [600/600], d_loss: 0.5687, g_loss: 1.6889, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0196.png
# Epoch [196/300], Step [200/600], d_loss: 0.5860, g_loss: 2.0579, D(x): 0.80, D(G(z)): 0.19
# Epoch [196/300], Step [400/600], d_loss: 0.6368, g_loss: 2.2735, D(x): 0.80, D(G(z)): 0.21
# Epoch [196/300], Step [600/600], d_loss: 0.7863, g_loss: 1.4654, D(x): 0.76, D(G(z)): 0.27
# Saving fake_images-0197.png
# Epoch [197/300], Step [200/600], d_loss: 0.6685, g_loss: 1.8442, D(x): 0.80, D(G(z)): 0.22
# Epoch [197/300], Step [400/600], d_loss: 0.5102, g_loss: 2.0068, D(x): 0.85, D(G(z)): 0.21
# Epoch [197/300], Step [600/600], d_loss: 0.4811, g_loss: 2.1302, D(x): 0.83, D(G(z)): 0.14
# Saving fake_images-0198.png
# Epoch [198/300], Step [200/600], d_loss: 0.4962, g_loss: 2.0754, D(x): 0.86, D(G(z)): 0.18
# Epoch [198/300], Step [400/600], d_loss: 0.5596, g_loss: 2.0202, D(x): 0.83, D(G(z)): 0.20
# Epoch [198/300], Step [600/600], d_loss: 0.6116, g_loss: 1.7405, D(x): 0.80, D(G(z)): 0.21
# Saving fake_images-0199.png
# Epoch [199/300], Step [200/600], d_loss: 0.5682, g_loss: 1.8744, D(x): 0.85, D(G(z)): 0.25
# Epoch [199/300], Step [400/600], d_loss: 0.5544, g_loss: 2.3946, D(x): 0.86, D(G(z)): 0.21
# Epoch [199/300], Step [600/600], d_loss: 0.5465, g_loss: 1.6804, D(x): 0.79, D(G(z)): 0.15
# Saving fake_images-0200.png
# Epoch [200/300], Step [200/600], d_loss: 0.5628, g_loss: 1.6317, D(x): 0.76, D(G(z)): 0.12
# Epoch [200/300], Step [400/600], d_loss: 0.5896, g_loss: 2.0890, D(x): 0.82, D(G(z)): 0.20
# Epoch [200/300], Step [600/600], d_loss: 0.5747, g_loss: 1.8292, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0201.png
# Epoch [201/300], Step [200/600], d_loss: 0.7752, g_loss: 2.1697, D(x): 0.87, D(G(z)): 0.35
# Epoch [201/300], Step [400/600], d_loss: 0.4995, g_loss: 2.1203, D(x): 0.84, D(G(z)): 0.18
# Epoch [201/300], Step [600/600], d_loss: 0.5211, g_loss: 1.7416, D(x): 0.80, D(G(z)): 0.15
# Saving fake_images-0202.png
# Epoch [202/300], Step [200/600], d_loss: 0.6088, g_loss: 1.6920, D(x): 0.79, D(G(z)): 0.16
# Epoch [202/300], Step [400/600], d_loss: 0.7059, g_loss: 2.1072, D(x): 0.81, D(G(z)): 0.24
# Epoch [202/300], Step [600/600], d_loss: 0.6093, g_loss: 1.6877, D(x): 0.77, D(G(z)): 0.16
# Saving fake_images-0203.png
# Epoch [203/300], Step [200/600], d_loss: 0.6973, g_loss: 2.2015, D(x): 0.79, D(G(z)): 0.23
# Epoch [203/300], Step [400/600], d_loss: 0.5957, g_loss: 1.6941, D(x): 0.81, D(G(z)): 0.21
# Epoch [203/300], Step [600/600], d_loss: 0.5773, g_loss: 2.4371, D(x): 0.85, D(G(z)): 0.21
# Saving fake_images-0204.png
# Epoch [204/300], Step [200/600], d_loss: 0.5947, g_loss: 2.0526, D(x): 0.78, D(G(z)): 0.15
# Epoch [204/300], Step [400/600], d_loss: 0.6187, g_loss: 2.3598, D(x): 0.83, D(G(z)): 0.19
# Epoch [204/300], Step [600/600], d_loss: 0.7836, g_loss: 1.6367, D(x): 0.73, D(G(z)): 0.17
# Saving fake_images-0205.png
# Epoch [205/300], Step [200/600], d_loss: 0.6321, g_loss: 1.8237, D(x): 0.77, D(G(z)): 0.15
# Epoch [205/300], Step [400/600], d_loss: 0.5845, g_loss: 2.5065, D(x): 0.81, D(G(z)): 0.17
# Epoch [205/300], Step [600/600], d_loss: 0.6229, g_loss: 2.2592, D(x): 0.81, D(G(z)): 0.21
# Saving fake_images-0206.png
# Epoch [206/300], Step [200/600], d_loss: 0.5838, g_loss: 2.0146, D(x): 0.82, D(G(z)): 0.20
# Epoch [206/300], Step [400/600], d_loss: 0.6526, g_loss: 2.4258, D(x): 0.80, D(G(z)): 0.20
# Epoch [206/300], Step [600/600], d_loss: 0.4784, g_loss: 2.1520, D(x): 0.87, D(G(z)): 0.21
# Saving fake_images-0207.png
# Epoch [207/300], Step [200/600], d_loss: 0.7524, g_loss: 1.5509, D(x): 0.72, D(G(z)): 0.16
# Epoch [207/300], Step [400/600], d_loss: 0.6448, g_loss: 2.4810, D(x): 0.81, D(G(z)): 0.21
# Epoch [207/300], Step [600/600], d_loss: 0.4846, g_loss: 2.2116, D(x): 0.82, D(G(z)): 0.15
# Saving fake_images-0208.png
# Epoch [208/300], Step [200/600], d_loss: 0.6953, g_loss: 1.8201, D(x): 0.75, D(G(z)): 0.19
# Epoch [208/300], Step [400/600], d_loss: 0.6406, g_loss: 2.1761, D(x): 0.84, D(G(z)): 0.26
# Epoch [208/300], Step [600/600], d_loss: 0.5645, g_loss: 2.4803, D(x): 0.87, D(G(z)): 0.22
# Saving fake_images-0209.png
# Epoch [209/300], Step [200/600], d_loss: 0.6372, g_loss: 2.8006, D(x): 0.84, D(G(z)): 0.23
# Epoch [209/300], Step [400/600], d_loss: 0.5624, g_loss: 2.0781, D(x): 0.78, D(G(z)): 0.12
# Epoch [209/300], Step [600/600], d_loss: 0.6698, g_loss: 1.8483, D(x): 0.82, D(G(z)): 0.23
# Saving fake_images-0210.png
# Epoch [210/300], Step [200/600], d_loss: 0.5672, g_loss: 2.4151, D(x): 0.83, D(G(z)): 0.18
# Epoch [210/300], Step [400/600], d_loss: 0.5730, g_loss: 1.5924, D(x): 0.79, D(G(z)): 0.18
# Epoch [210/300], Step [600/600], d_loss: 0.6614, g_loss: 1.4557, D(x): 0.77, D(G(z)): 0.19
# Saving fake_images-0211.png
# Epoch [211/300], Step [200/600], d_loss: 0.6585, g_loss: 2.3444, D(x): 0.83, D(G(z)): 0.23
# Epoch [211/300], Step [400/600], d_loss: 0.5855, g_loss: 2.0126, D(x): 0.79, D(G(z)): 0.16
# Epoch [211/300], Step [600/600], d_loss: 0.6450, g_loss: 2.1150, D(x): 0.85, D(G(z)): 0.24
# Saving fake_images-0212.png
# Epoch [212/300], Step [200/600], d_loss: 0.6310, g_loss: 1.6104, D(x): 0.77, D(G(z)): 0.19
# Epoch [212/300], Step [400/600], d_loss: 0.5499, g_loss: 2.0087, D(x): 0.84, D(G(z)): 0.24
# Epoch [212/300], Step [600/600], d_loss: 0.4939, g_loss: 2.2902, D(x): 0.83, D(G(z)): 0.16
# Saving fake_images-0213.png
# Epoch [213/300], Step [200/600], d_loss: 0.5296, g_loss: 2.6523, D(x): 0.85, D(G(z)): 0.19
# Epoch [213/300], Step [400/600], d_loss: 0.5861, g_loss: 2.1161, D(x): 0.84, D(G(z)): 0.21
# Epoch [213/300], Step [600/600], d_loss: 0.6915, g_loss: 1.7830, D(x): 0.78, D(G(z)): 0.17
# Saving fake_images-0214.png
# Epoch [214/300], Step [200/600], d_loss: 0.6688, g_loss: 1.6347, D(x): 0.74, D(G(z)): 0.14
# Epoch [214/300], Step [400/600], d_loss: 0.7078, g_loss: 1.8018, D(x): 0.78, D(G(z)): 0.21
# Epoch [214/300], Step [600/600], d_loss: 0.6818, g_loss: 2.1421, D(x): 0.79, D(G(z)): 0.21
# Saving fake_images-0215.png
# Epoch [215/300], Step [200/600], d_loss: 0.4900, g_loss: 2.2493, D(x): 0.82, D(G(z)): 0.15
# Epoch [215/300], Step [400/600], d_loss: 0.6489, g_loss: 1.8976, D(x): 0.80, D(G(z)): 0.19
# Epoch [215/300], Step [600/600], d_loss: 0.6071, g_loss: 1.8797, D(x): 0.83, D(G(z)): 0.23
# Saving fake_images-0216.png
# Epoch [216/300], Step [200/600], d_loss: 0.6482, g_loss: 2.4386, D(x): 0.85, D(G(z)): 0.27
# Epoch [216/300], Step [400/600], d_loss: 0.6368, g_loss: 1.8824, D(x): 0.78, D(G(z)): 0.18
# Epoch [216/300], Step [600/600], d_loss: 0.4076, g_loss: 2.1464, D(x): 0.88, D(G(z)): 0.17
# Saving fake_images-0217.png
# Epoch [217/300], Step [200/600], d_loss: 0.5824, g_loss: 1.9875, D(x): 0.80, D(G(z)): 0.18
# Epoch [217/300], Step [400/600], d_loss: 0.5867, g_loss: 2.2305, D(x): 0.84, D(G(z)): 0.22
# Epoch [217/300], Step [600/600], d_loss: 0.6308, g_loss: 2.1168, D(x): 0.75, D(G(z)): 0.11
# Saving fake_images-0218.png
# Epoch [218/300], Step [200/600], d_loss: 0.5807, g_loss: 2.1533, D(x): 0.79, D(G(z)): 0.17
# Epoch [218/300], Step [400/600], d_loss: 0.7152, g_loss: 1.8296, D(x): 0.79, D(G(z)): 0.22
# Epoch [218/300], Step [600/600], d_loss: 0.5968, g_loss: 2.0883, D(x): 0.82, D(G(z)): 0.23
# Saving fake_images-0219.png
# Epoch [219/300], Step [200/600], d_loss: 0.6263, g_loss: 1.8610, D(x): 0.78, D(G(z)): 0.18
# Epoch [219/300], Step [400/600], d_loss: 0.8173, g_loss: 2.3566, D(x): 0.82, D(G(z)): 0.28
# Epoch [219/300], Step [600/600], d_loss: 0.6480, g_loss: 2.0693, D(x): 0.79, D(G(z)): 0.18
# Saving fake_images-0220.png
# Epoch [220/300], Step [200/600], d_loss: 0.4476, g_loss: 2.6594, D(x): 0.88, D(G(z)): 0.20
# Epoch [220/300], Step [400/600], d_loss: 0.6116, g_loss: 1.7082, D(x): 0.77, D(G(z)): 0.15
# Epoch [220/300], Step [600/600], d_loss: 0.5999, g_loss: 1.9666, D(x): 0.80, D(G(z)): 0.14
# Saving fake_images-0221.png
# Epoch [221/300], Step [200/600], d_loss: 0.5628, g_loss: 1.9964, D(x): 0.80, D(G(z)): 0.15
# Epoch [221/300], Step [400/600], d_loss: 0.6689, g_loss: 2.6185, D(x): 0.88, D(G(z)): 0.28
# Epoch [221/300], Step [600/600], d_loss: 0.5977, g_loss: 1.8842, D(x): 0.79, D(G(z)): 0.17
# Saving fake_images-0222.png
# Epoch [222/300], Step [200/600], d_loss: 0.6008, g_loss: 1.9887, D(x): 0.78, D(G(z)): 0.12
# Epoch [222/300], Step [400/600], d_loss: 0.7532, g_loss: 1.7104, D(x): 0.75, D(G(z)): 0.16
# Epoch [222/300], Step [600/600], d_loss: 0.5383, g_loss: 2.3187, D(x): 0.84, D(G(z)): 0.19
# Saving fake_images-0223.png
# Epoch [223/300], Step [200/600], d_loss: 0.6157, g_loss: 2.1222, D(x): 0.79, D(G(z)): 0.14
# Epoch [223/300], Step [400/600], d_loss: 0.6585, g_loss: 2.0220, D(x): 0.77, D(G(z)): 0.21
# Epoch [223/300], Step [600/600], d_loss: 0.5858, g_loss: 1.6626, D(x): 0.78, D(G(z)): 0.12
# Saving fake_images-0224.png
# Epoch [224/300], Step [200/600], d_loss: 0.4689, g_loss: 2.2059, D(x): 0.83, D(G(z)): 0.13
# Epoch [224/300], Step [400/600], d_loss: 0.5474, g_loss: 2.5189, D(x): 0.88, D(G(z)): 0.23
# Epoch [224/300], Step [600/600], d_loss: 0.5023, g_loss: 2.3657, D(x): 0.87, D(G(z)): 0.22
# Saving fake_images-0225.png
# Epoch [225/300], Step [200/600], d_loss: 0.5126, g_loss: 2.1003, D(x): 0.84, D(G(z)): 0.18
# Epoch [225/300], Step [400/600], d_loss: 0.6310, g_loss: 2.1030, D(x): 0.80, D(G(z)): 0.20
# Epoch [225/300], Step [600/600], d_loss: 0.5602, g_loss: 2.0328, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0226.png
# Epoch [226/300], Step [200/600], d_loss: 0.5720, g_loss: 1.7086, D(x): 0.80, D(G(z)): 0.17
# Epoch [226/300], Step [400/600], d_loss: 0.5939, g_loss: 2.6162, D(x): 0.84, D(G(z)): 0.22
# Epoch [226/300], Step [600/600], d_loss: 0.6672, g_loss: 1.6006, D(x): 0.80, D(G(z)): 0.23
# Saving fake_images-0227.png
# Epoch [227/300], Step [200/600], d_loss: 0.7620, g_loss: 1.7354, D(x): 0.75, D(G(z)): 0.16
# Epoch [227/300], Step [400/600], d_loss: 0.6709, g_loss: 2.1136, D(x): 0.74, D(G(z)): 0.10
# Epoch [227/300], Step [600/600], d_loss: 0.5936, g_loss: 1.5946, D(x): 0.78, D(G(z)): 0.14
# Saving fake_images-0228.png
# Epoch [228/300], Step [200/600], d_loss: 0.5418, g_loss: 1.9289, D(x): 0.80, D(G(z)): 0.16
# Epoch [228/300], Step [400/600], d_loss: 0.6351, g_loss: 2.3046, D(x): 0.83, D(G(z)): 0.23
# Epoch [228/300], Step [600/600], d_loss: 0.6128, g_loss: 1.9738, D(x): 0.80, D(G(z)): 0.13
# Saving fake_images-0229.png
# Epoch [229/300], Step [200/600], d_loss: 0.6096, g_loss: 2.1063, D(x): 0.78, D(G(z)): 0.11
# Epoch [229/300], Step [400/600], d_loss: 0.6965, g_loss: 1.3960, D(x): 0.79, D(G(z)): 0.18
# Epoch [229/300], Step [600/600], d_loss: 0.5582, g_loss: 1.9673, D(x): 0.81, D(G(z)): 0.18
# Saving fake_images-0230.png
# Epoch [230/300], Step [200/600], d_loss: 0.5510, g_loss: 2.2827, D(x): 0.80, D(G(z)): 0.16
# Epoch [230/300], Step [400/600], d_loss: 0.5506, g_loss: 1.9789, D(x): 0.82, D(G(z)): 0.15
# Epoch [230/300], Step [600/600], d_loss: 0.7615, g_loss: 1.6596, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0231.png
# Epoch [231/300], Step [200/600], d_loss: 0.6467, g_loss: 2.0584, D(x): 0.79, D(G(z)): 0.20
# Epoch [231/300], Step [400/600], d_loss: 0.5798, g_loss: 1.9621, D(x): 0.82, D(G(z)): 0.20
# Epoch [231/300], Step [600/600], d_loss: 0.6167, g_loss: 2.3966, D(x): 0.86, D(G(z)): 0.25
# Saving fake_images-0232.png
# Epoch [232/300], Step [200/600], d_loss: 0.6596, g_loss: 2.2183, D(x): 0.77, D(G(z)): 0.16
# Epoch [232/300], Step [400/600], d_loss: 0.5336, g_loss: 1.9399, D(x): 0.82, D(G(z)): 0.15
# Epoch [232/300], Step [600/600], d_loss: 0.4492, g_loss: 2.0659, D(x): 0.85, D(G(z)): 0.16
# Saving fake_images-0233.png
# Epoch [233/300], Step [200/600], d_loss: 0.5765, g_loss: 2.0703, D(x): 0.84, D(G(z)): 0.20
# Epoch [233/300], Step [400/600], d_loss: 0.5445, g_loss: 2.1990, D(x): 0.85, D(G(z)): 0.19
# Epoch [233/300], Step [600/600], d_loss: 0.5878, g_loss: 1.5204, D(x): 0.77, D(G(z)): 0.13
# Saving fake_images-0234.png
# Epoch [234/300], Step [200/600], d_loss: 0.6403, g_loss: 1.7669, D(x): 0.77, D(G(z)): 0.18
# Epoch [234/300], Step [400/600], d_loss: 0.6225, g_loss: 1.8383, D(x): 0.74, D(G(z)): 0.10
# Epoch [234/300], Step [600/600], d_loss: 0.4949, g_loss: 2.0222, D(x): 0.85, D(G(z)): 0.16
# Saving fake_images-0235.png
# Epoch [235/300], Step [200/600], d_loss: 0.5512, g_loss: 2.0699, D(x): 0.83, D(G(z)): 0.18
# Epoch [235/300], Step [400/600], d_loss: 0.5012, g_loss: 2.2771, D(x): 0.85, D(G(z)): 0.17
# Epoch [235/300], Step [600/600], d_loss: 0.6963, g_loss: 2.4361, D(x): 0.78, D(G(z)): 0.14
# Saving fake_images-0236.png
# Epoch [236/300], Step [200/600], d_loss: 0.5684, g_loss: 2.0239, D(x): 0.81, D(G(z)): 0.17
# Epoch [236/300], Step [400/600], d_loss: 0.6575, g_loss: 1.9121, D(x): 0.77, D(G(z)): 0.19
# Epoch [236/300], Step [600/600], d_loss: 0.5861, g_loss: 1.9070, D(x): 0.81, D(G(z)): 0.19
# Saving fake_images-0237.png
# Epoch [237/300], Step [200/600], d_loss: 0.5398, g_loss: 2.3004, D(x): 0.86, D(G(z)): 0.20
# Epoch [237/300], Step [400/600], d_loss: 0.6068, g_loss: 2.0822, D(x): 0.81, D(G(z)): 0.21
# Epoch [237/300], Step [600/600], d_loss: 0.4404, g_loss: 1.9381, D(x): 0.84, D(G(z)): 0.13
# Saving fake_images-0238.png
# Epoch [238/300], Step [200/600], d_loss: 0.6268, g_loss: 2.1516, D(x): 0.85, D(G(z)): 0.27
# Epoch [238/300], Step [400/600], d_loss: 0.5460, g_loss: 1.6706, D(x): 0.80, D(G(z)): 0.17
# Epoch [238/300], Step [600/600], d_loss: 0.4926, g_loss: 2.1375, D(x): 0.83, D(G(z)): 0.16
# Saving fake_images-0239.png
# Epoch [239/300], Step [200/600], d_loss: 0.4804, g_loss: 2.2884, D(x): 0.83, D(G(z)): 0.14
# Epoch [239/300], Step [400/600], d_loss: 0.6160, g_loss: 1.8324, D(x): 0.84, D(G(z)): 0.22
# Epoch [239/300], Step [600/600], d_loss: 0.7160, g_loss: 2.4066, D(x): 0.84, D(G(z)): 0.27
# Saving fake_images-0240.png
# Epoch [240/300], Step [200/600], d_loss: 0.6880, g_loss: 2.0940, D(x): 0.84, D(G(z)): 0.28
# Epoch [240/300], Step [400/600], d_loss: 0.4776, g_loss: 2.2974, D(x): 0.85, D(G(z)): 0.16
# Epoch [240/300], Step [600/600], d_loss: 0.7339, g_loss: 2.1077, D(x): 0.75, D(G(z)): 0.16
# Saving fake_images-0241.png
# Epoch [241/300], Step [200/600], d_loss: 0.6126, g_loss: 1.9187, D(x): 0.78, D(G(z)): 0.17
# Epoch [241/300], Step [400/600], d_loss: 0.6077, g_loss: 1.9985, D(x): 0.80, D(G(z)): 0.18
# Epoch [241/300], Step [600/600], d_loss: 0.5971, g_loss: 2.3272, D(x): 0.81, D(G(z)): 0.17
# Saving fake_images-0242.png
# Epoch [242/300], Step [200/600], d_loss: 0.5790, g_loss: 2.2014, D(x): 0.85, D(G(z)): 0.25
# Epoch [242/300], Step [400/600], d_loss: 0.6120, g_loss: 1.6548, D(x): 0.78, D(G(z)): 0.16
# Epoch [242/300], Step [600/600], d_loss: 0.5769, g_loss: 2.3569, D(x): 0.88, D(G(z)): 0.26
# Saving fake_images-0243.png
# Epoch [243/300], Step [200/600], d_loss: 0.5670, g_loss: 2.2569, D(x): 0.84, D(G(z)): 0.21
# Epoch [243/300], Step [400/600], d_loss: 0.4299, g_loss: 3.0044, D(x): 0.89, D(G(z)): 0.19
# Epoch [243/300], Step [600/600], d_loss: 0.4184, g_loss: 2.4821, D(x): 0.90, D(G(z)): 0.19
# Saving fake_images-0244.png
# Epoch [244/300], Step [200/600], d_loss: 0.6963, g_loss: 2.3510, D(x): 0.83, D(G(z)): 0.23
# Epoch [244/300], Step [400/600], d_loss: 0.5963, g_loss: 2.2923, D(x): 0.89, D(G(z)): 0.27
# Epoch [244/300], Step [600/600], d_loss: 0.5681, g_loss: 1.9384, D(x): 0.82, D(G(z)): 0.16
# Saving fake_images-0245.png
# Epoch [245/300], Step [200/600], d_loss: 0.7182, g_loss: 2.1094, D(x): 0.86, D(G(z)): 0.30
# Epoch [245/300], Step [400/600], d_loss: 0.5749, g_loss: 1.9065, D(x): 0.77, D(G(z)): 0.13
# Epoch [245/300], Step [600/600], d_loss: 0.7212, g_loss: 1.3678, D(x): 0.72, D(G(z)): 0.17
# Saving fake_images-0246.png
# Epoch [246/300], Step [200/600], d_loss: 0.6238, g_loss: 2.3397, D(x): 0.82, D(G(z)): 0.20
# Epoch [246/300], Step [400/600], d_loss: 0.7326, g_loss: 2.1818, D(x): 0.76, D(G(z)): 0.18
# Epoch [246/300], Step [600/600], d_loss: 0.7217, g_loss: 1.7414, D(x): 0.77, D(G(z)): 0.22
# Saving fake_images-0247.png
# Epoch [247/300], Step [200/600], d_loss: 0.5041, g_loss: 2.0038, D(x): 0.80, D(G(z)): 0.12
# Epoch [247/300], Step [400/600], d_loss: 0.5124, g_loss: 2.1580, D(x): 0.85, D(G(z)): 0.20
# Epoch [247/300], Step [600/600], d_loss: 0.6136, g_loss: 1.9404, D(x): 0.82, D(G(z)): 0.20
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.5949, g_loss: 1.9192, D(x): 0.84, D(G(z)): 0.25
# Epoch [248/300], Step [400/600], d_loss: 0.5714, g_loss: 1.8145, D(x): 0.82, D(G(z)): 0.19
# Epoch [248/300], Step [600/600], d_loss: 0.6067, g_loss: 1.7265, D(x): 0.81, D(G(z)): 0.23
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.5793, g_loss: 2.2698, D(x): 0.89, D(G(z)): 0.24
# Epoch [249/300], Step [400/600], d_loss: 0.7497, g_loss: 2.0408, D(x): 0.80, D(G(z)): 0.20
# Epoch [249/300], Step [600/600], d_loss: 0.5144, g_loss: 2.1000, D(x): 0.83, D(G(z)): 0.15
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.5244, g_loss: 2.0808, D(x): 0.82, D(G(z)): 0.18
# Epoch [250/300], Step [400/600], d_loss: 0.5995, g_loss: 1.7159, D(x): 0.78, D(G(z)): 0.17
# Epoch [250/300], Step [600/600], d_loss: 0.4712, g_loss: 2.1988, D(x): 0.86, D(G(z)): 0.17
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.5029, g_loss: 2.3489, D(x): 0.88, D(G(z)): 0.19
# Epoch [251/300], Step [400/600], d_loss: 0.5393, g_loss: 2.1718, D(x): 0.81, D(G(z)): 0.14
# Epoch [251/300], Step [600/600], d_loss: 0.6938, g_loss: 1.5385, D(x): 0.77, D(G(z)): 0.14
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.5281, g_loss: 2.1857, D(x): 0.89, D(G(z)): 0.23
# Epoch [252/300], Step [400/600], d_loss: 0.5055, g_loss: 2.2241, D(x): 0.83, D(G(z)): 0.15
# Epoch [252/300], Step [600/600], d_loss: 0.7255, g_loss: 1.7117, D(x): 0.73, D(G(z)): 0.13
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.6255, g_loss: 2.2894, D(x): 0.82, D(G(z)): 0.20
# Epoch [253/300], Step [400/600], d_loss: 0.6017, g_loss: 2.5847, D(x): 0.86, D(G(z)): 0.19
# Epoch [253/300], Step [600/600], d_loss: 0.6077, g_loss: 2.0847, D(x): 0.76, D(G(z)): 0.11
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.6161, g_loss: 1.6891, D(x): 0.79, D(G(z)): 0.18
# Epoch [254/300], Step [400/600], d_loss: 0.4536, g_loss: 2.4888, D(x): 0.86, D(G(z)): 0.16
# Epoch [254/300], Step [600/600], d_loss: 0.8094, g_loss: 1.2673, D(x): 0.69, D(G(z)): 0.13
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.6334, g_loss: 1.8182, D(x): 0.77, D(G(z)): 0.19
# Epoch [255/300], Step [400/600], d_loss: 0.5306, g_loss: 2.2339, D(x): 0.84, D(G(z)): 0.18
# Epoch [255/300], Step [600/600], d_loss: 0.4891, g_loss: 2.2029, D(x): 0.80, D(G(z)): 0.10
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.5392, g_loss: 1.8789, D(x): 0.82, D(G(z)): 0.14
# Epoch [256/300], Step [400/600], d_loss: 0.7979, g_loss: 1.6035, D(x): 0.71, D(G(z)): 0.13
# Epoch [256/300], Step [600/600], d_loss: 0.5701, g_loss: 2.0510, D(x): 0.85, D(G(z)): 0.20
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.5841, g_loss: 2.6793, D(x): 0.83, D(G(z)): 0.19
# Epoch [257/300], Step [400/600], d_loss: 0.6262, g_loss: 1.9496, D(x): 0.81, D(G(z)): 0.19
# Epoch [257/300], Step [600/600], d_loss: 0.4962, g_loss: 1.9770, D(x): 0.85, D(G(z)): 0.16
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.6087, g_loss: 2.1236, D(x): 0.77, D(G(z)): 0.15
# Epoch [258/300], Step [400/600], d_loss: 0.5498, g_loss: 2.0178, D(x): 0.85, D(G(z)): 0.21
# Epoch [258/300], Step [600/600], d_loss: 0.6288, g_loss: 2.5732, D(x): 0.86, D(G(z)): 0.25
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.6014, g_loss: 1.7093, D(x): 0.81, D(G(z)): 0.23
# Epoch [259/300], Step [400/600], d_loss: 0.5832, g_loss: 2.0893, D(x): 0.79, D(G(z)): 0.15
# Epoch [259/300], Step [600/600], d_loss: 0.5305, g_loss: 2.6318, D(x): 0.87, D(G(z)): 0.18
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.5286, g_loss: 1.9482, D(x): 0.83, D(G(z)): 0.16
# Epoch [260/300], Step [400/600], d_loss: 0.6464, g_loss: 1.8385, D(x): 0.79, D(G(z)): 0.18
# Epoch [260/300], Step [600/600], d_loss: 0.5928, g_loss: 2.5325, D(x): 0.80, D(G(z)): 0.15
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.5150, g_loss: 2.3661, D(x): 0.86, D(G(z)): 0.20
# Epoch [261/300], Step [400/600], d_loss: 0.7183, g_loss: 1.8265, D(x): 0.76, D(G(z)): 0.23
# Epoch [261/300], Step [600/600], d_loss: 0.6466, g_loss: 1.6283, D(x): 0.79, D(G(z)): 0.21
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.4262, g_loss: 2.1406, D(x): 0.84, D(G(z)): 0.12
# Epoch [262/300], Step [400/600], d_loss: 0.4912, g_loss: 2.6928, D(x): 0.86, D(G(z)): 0.20
# Epoch [262/300], Step [600/600], d_loss: 0.6957, g_loss: 2.2158, D(x): 0.83, D(G(z)): 0.26
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.5462, g_loss: 2.2124, D(x): 0.85, D(G(z)): 0.21
# Epoch [263/300], Step [400/600], d_loss: 0.5124, g_loss: 2.4346, D(x): 0.86, D(G(z)): 0.18
# Epoch [263/300], Step [600/600], d_loss: 0.5172, g_loss: 2.1480, D(x): 0.80, D(G(z)): 0.14
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 0.7966, g_loss: 2.8510, D(x): 0.85, D(G(z)): 0.24
# Epoch [264/300], Step [400/600], d_loss: 0.7099, g_loss: 1.9027, D(x): 0.77, D(G(z)): 0.21
# Epoch [264/300], Step [600/600], d_loss: 0.6529, g_loss: 1.6862, D(x): 0.76, D(G(z)): 0.20
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.5786, g_loss: 2.2868, D(x): 0.84, D(G(z)): 0.18
# Epoch [265/300], Step [400/600], d_loss: 0.6531, g_loss: 2.0087, D(x): 0.77, D(G(z)): 0.15
# Epoch [265/300], Step [600/600], d_loss: 0.5885, g_loss: 1.9609, D(x): 0.81, D(G(z)): 0.17
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.4950, g_loss: 2.4606, D(x): 0.83, D(G(z)): 0.14
# Epoch [266/300], Step [400/600], d_loss: 0.5561, g_loss: 1.9995, D(x): 0.81, D(G(z)): 0.20
# Epoch [266/300], Step [600/600], d_loss: 0.6378, g_loss: 2.6852, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.6949, g_loss: 2.2564, D(x): 0.84, D(G(z)): 0.28
# Epoch [267/300], Step [400/600], d_loss: 0.4817, g_loss: 2.0516, D(x): 0.89, D(G(z)): 0.25
# Epoch [267/300], Step [600/600], d_loss: 0.5784, g_loss: 1.8142, D(x): 0.82, D(G(z)): 0.21
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.5927, g_loss: 2.4216, D(x): 0.84, D(G(z)): 0.21
# Epoch [268/300], Step [400/600], d_loss: 0.5582, g_loss: 2.5134, D(x): 0.83, D(G(z)): 0.16
# Epoch [268/300], Step [600/600], d_loss: 0.5183, g_loss: 1.7612, D(x): 0.84, D(G(z)): 0.18
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.4425, g_loss: 1.8474, D(x): 0.88, D(G(z)): 0.20
# Epoch [269/300], Step [400/600], d_loss: 0.4337, g_loss: 2.2296, D(x): 0.88, D(G(z)): 0.18
# Epoch [269/300], Step [600/600], d_loss: 0.5082, g_loss: 2.2788, D(x): 0.84, D(G(z)): 0.14
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.7535, g_loss: 2.0299, D(x): 0.73, D(G(z)): 0.15
# Epoch [270/300], Step [400/600], d_loss: 0.5494, g_loss: 2.0216, D(x): 0.83, D(G(z)): 0.18
# Epoch [270/300], Step [600/600], d_loss: 0.4656, g_loss: 2.5112, D(x): 0.91, D(G(z)): 0.21
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.6083, g_loss: 1.9333, D(x): 0.79, D(G(z)): 0.17
# Epoch [271/300], Step [400/600], d_loss: 0.5539, g_loss: 2.2095, D(x): 0.80, D(G(z)): 0.12
# Epoch [271/300], Step [600/600], d_loss: 0.5089, g_loss: 2.0522, D(x): 0.87, D(G(z)): 0.22
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.6507, g_loss: 2.0462, D(x): 0.80, D(G(z)): 0.17
# Epoch [272/300], Step [400/600], d_loss: 0.8116, g_loss: 2.5491, D(x): 0.82, D(G(z)): 0.25
# Epoch [272/300], Step [600/600], d_loss: 0.5953, g_loss: 1.7877, D(x): 0.81, D(G(z)): 0.21
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.5992, g_loss: 2.0356, D(x): 0.83, D(G(z)): 0.19
# Epoch [273/300], Step [400/600], d_loss: 0.6301, g_loss: 2.3040, D(x): 0.82, D(G(z)): 0.22
# Epoch [273/300], Step [600/600], d_loss: 0.5637, g_loss: 2.3506, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.6626, g_loss: 1.8747, D(x): 0.75, D(G(z)): 0.14
# Epoch [274/300], Step [400/600], d_loss: 0.6615, g_loss: 2.9193, D(x): 0.87, D(G(z)): 0.24
# Epoch [274/300], Step [600/600], d_loss: 0.6288, g_loss: 2.4184, D(x): 0.85, D(G(z)): 0.24
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.5589, g_loss: 2.0707, D(x): 0.83, D(G(z)): 0.19
# Epoch [275/300], Step [400/600], d_loss: 0.8460, g_loss: 1.5736, D(x): 0.69, D(G(z)): 0.08
# Epoch [275/300], Step [600/600], d_loss: 0.3409, g_loss: 2.4654, D(x): 0.89, D(G(z)): 0.14
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.6028, g_loss: 1.9402, D(x): 0.80, D(G(z)): 0.18
# Epoch [276/300], Step [400/600], d_loss: 0.6055, g_loss: 1.5818, D(x): 0.86, D(G(z)): 0.22
# Epoch [276/300], Step [600/600], d_loss: 0.6099, g_loss: 2.2065, D(x): 0.77, D(G(z)): 0.13
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.4802, g_loss: 2.3521, D(x): 0.84, D(G(z)): 0.13
# Epoch [277/300], Step [400/600], d_loss: 0.6434, g_loss: 1.6375, D(x): 0.80, D(G(z)): 0.21
# Epoch [277/300], Step [600/600], d_loss: 0.5917, g_loss: 2.2419, D(x): 0.86, D(G(z)): 0.22
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.5128, g_loss: 2.4908, D(x): 0.90, D(G(z)): 0.23
# Epoch [278/300], Step [400/600], d_loss: 0.4566, g_loss: 2.2350, D(x): 0.87, D(G(z)): 0.19
# Epoch [278/300], Step [600/600], d_loss: 0.6225, g_loss: 2.7014, D(x): 0.84, D(G(z)): 0.20
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.6264, g_loss: 1.9234, D(x): 0.78, D(G(z)): 0.13
# Epoch [279/300], Step [400/600], d_loss: 0.4961, g_loss: 2.3989, D(x): 0.85, D(G(z)): 0.17
# Epoch [279/300], Step [600/600], d_loss: 0.4464, g_loss: 2.4095, D(x): 0.90, D(G(z)): 0.20
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.6486, g_loss: 2.2111, D(x): 0.81, D(G(z)): 0.14
# Epoch [280/300], Step [400/600], d_loss: 0.4200, g_loss: 2.2023, D(x): 0.87, D(G(z)): 0.16
# Epoch [280/300], Step [600/600], d_loss: 0.4965, g_loss: 2.2000, D(x): 0.84, D(G(z)): 0.15
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.5624, g_loss: 2.0050, D(x): 0.86, D(G(z)): 0.24
# Epoch [281/300], Step [400/600], d_loss: 0.7090, g_loss: 2.3448, D(x): 0.87, D(G(z)): 0.29
# Epoch [281/300], Step [600/600], d_loss: 0.5859, g_loss: 2.7551, D(x): 0.89, D(G(z)): 0.18
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.4630, g_loss: 2.6271, D(x): 0.85, D(G(z)): 0.16
# Epoch [282/300], Step [400/600], d_loss: 0.5681, g_loss: 2.1206, D(x): 0.81, D(G(z)): 0.17
# Epoch [282/300], Step [600/600], d_loss: 0.5153, g_loss: 2.2774, D(x): 0.83, D(G(z)): 0.15
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.4637, g_loss: 1.8721, D(x): 0.85, D(G(z)): 0.15
# Epoch [283/300], Step [400/600], d_loss: 0.5551, g_loss: 2.0048, D(x): 0.80, D(G(z)): 0.13
# Epoch [283/300], Step [600/600], d_loss: 0.5367, g_loss: 1.9078, D(x): 0.81, D(G(z)): 0.17
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.5084, g_loss: 1.8697, D(x): 0.81, D(G(z)): 0.13
# Epoch [284/300], Step [400/600], d_loss: 0.6538, g_loss: 2.5503, D(x): 0.88, D(G(z)): 0.30
# Epoch [284/300], Step [600/600], d_loss: 0.5596, g_loss: 2.0324, D(x): 0.84, D(G(z)): 0.17
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.5108, g_loss: 2.3540, D(x): 0.82, D(G(z)): 0.15
# Epoch [285/300], Step [400/600], d_loss: 0.6318, g_loss: 2.8998, D(x): 0.86, D(G(z)): 0.24
# Epoch [285/300], Step [600/600], d_loss: 0.6176, g_loss: 2.6240, D(x): 0.90, D(G(z)): 0.29
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.5278, g_loss: 2.1807, D(x): 0.83, D(G(z)): 0.15
# Epoch [286/300], Step [400/600], d_loss: 0.7060, g_loss: 2.0081, D(x): 0.78, D(G(z)): 0.20
# Epoch [286/300], Step [600/600], d_loss: 0.5143, g_loss: 2.0991, D(x): 0.86, D(G(z)): 0.20
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.5434, g_loss: 1.9631, D(x): 0.81, D(G(z)): 0.15
# Epoch [287/300], Step [400/600], d_loss: 0.5174, g_loss: 2.1689, D(x): 0.80, D(G(z)): 0.11
# Epoch [287/300], Step [600/600], d_loss: 0.4622, g_loss: 2.6118, D(x): 0.85, D(G(z)): 0.13
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.6456, g_loss: 1.8632, D(x): 0.79, D(G(z)): 0.16
# Epoch [288/300], Step [400/600], d_loss: 0.4284, g_loss: 2.1396, D(x): 0.89, D(G(z)): 0.19
# Epoch [288/300], Step [600/600], d_loss: 0.4316, g_loss: 2.2988, D(x): 0.88, D(G(z)): 0.19
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.5719, g_loss: 1.9850, D(x): 0.81, D(G(z)): 0.16
# Epoch [289/300], Step [400/600], d_loss: 0.5268, g_loss: 1.9781, D(x): 0.88, D(G(z)): 0.23
# Epoch [289/300], Step [600/600], d_loss: 0.4515, g_loss: 1.8376, D(x): 0.85, D(G(z)): 0.16
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.6666, g_loss: 2.1261, D(x): 0.75, D(G(z)): 0.13
# Epoch [290/300], Step [400/600], d_loss: 0.5145, g_loss: 1.6542, D(x): 0.82, D(G(z)): 0.14
# Epoch [290/300], Step [600/600], d_loss: 0.5562, g_loss: 1.9017, D(x): 0.85, D(G(z)): 0.20
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.5556, g_loss: 2.2452, D(x): 0.82, D(G(z)): 0.17
# Epoch [291/300], Step [400/600], d_loss: 0.3649, g_loss: 2.7329, D(x): 0.88, D(G(z)): 0.12
# Epoch [291/300], Step [600/600], d_loss: 0.4586, g_loss: 2.4954, D(x): 0.88, D(G(z)): 0.16
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.5078, g_loss: 2.5760, D(x): 0.83, D(G(z)): 0.13
# Epoch [292/300], Step [400/600], d_loss: 0.6641, g_loss: 2.6598, D(x): 0.81, D(G(z)): 0.18
# Epoch [292/300], Step [600/600], d_loss: 0.6566, g_loss: 1.8064, D(x): 0.82, D(G(z)): 0.22
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.5543, g_loss: 1.7887, D(x): 0.79, D(G(z)): 0.10
# Epoch [293/300], Step [400/600], d_loss: 0.7135, g_loss: 2.6236, D(x): 0.85, D(G(z)): 0.25
# Epoch [293/300], Step [600/600], d_loss: 0.4585, g_loss: 2.4379, D(x): 0.87, D(G(z)): 0.15
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.5588, g_loss: 1.9741, D(x): 0.90, D(G(z)): 0.24
# Epoch [294/300], Step [400/600], d_loss: 0.6981, g_loss: 1.7293, D(x): 0.72, D(G(z)): 0.08
# Epoch [294/300], Step [600/600], d_loss: 0.4731, g_loss: 2.2297, D(x): 0.88, D(G(z)): 0.19
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.4744, g_loss: 2.0929, D(x): 0.84, D(G(z)): 0.17
# Epoch [295/300], Step [400/600], d_loss: 0.5282, g_loss: 2.0831, D(x): 0.79, D(G(z)): 0.12
# Epoch [295/300], Step [600/600], d_loss: 0.6144, g_loss: 1.7631, D(x): 0.80, D(G(z)): 0.18
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.4797, g_loss: 2.0570, D(x): 0.81, D(G(z)): 0.10
# Epoch [296/300], Step [400/600], d_loss: 0.5283, g_loss: 2.5827, D(x): 0.86, D(G(z)): 0.18
# Epoch [296/300], Step [600/600], d_loss: 0.5502, g_loss: 2.1076, D(x): 0.83, D(G(z)): 0.21
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.6422, g_loss: 2.0924, D(x): 0.83, D(G(z)): 0.22
# Epoch [297/300], Step [400/600], d_loss: 0.6457, g_loss: 2.4435, D(x): 0.77, D(G(z)): 0.12
# Epoch [297/300], Step [600/600], d_loss: 0.4929, g_loss: 2.1680, D(x): 0.88, D(G(z)): 0.19
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.4462, g_loss: 2.4640, D(x): 0.86, D(G(z)): 0.11
# Epoch [298/300], Step [400/600], d_loss: 0.5042, g_loss: 2.1495, D(x): 0.87, D(G(z)): 0.20
# Epoch [298/300], Step [600/600], d_loss: 0.5097, g_loss: 2.0395, D(x): 0.81, D(G(z)): 0.14
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.6067, g_loss: 2.0323, D(x): 0.85, D(G(z)): 0.23
# Epoch [299/300], Step [400/600], d_loss: 0.5391, g_loss: 2.3312, D(x): 0.89, D(G(z)): 0.24
# Epoch [299/300], Step [600/600], d_loss: 0.4702, g_loss: 2.0274, D(x): 0.82, D(G(z)): 0.11
# Saving fake_images-0300.png
# CPU times: total: 50min 59s
# Wall time: 39min 18s

# %%
# show output after epochs training
from IPython.display import Image as IPImage
IPImage(os.path.join(sample_dir, "fake_images-0225.png"))

# %%
# show the discrimator loss and generator loss
plt.plot(d_losses, "-")
plt.plot(g_losses, "-")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(["Discriminator", "Generator"])
plt.title("Losses");

# %%
# plot the accuracy of discrimator
plt.plot(real_scores, "-")
plt.plot(fake_scores, "-")
plt.xlabel("epoch")
plt.ylabel("score")
plt.legend(["Real Score", "Fake score"])
plt.title("Scores");

# %% [markdown]
# ## 2. DCGAN

# %% [markdown]
# *Source: <a href="https://arxiv.org/pdf/1511.06434v2.pdf" target="_blank">Radford, Alec, Luke Metz, and Soumith Chintala. "Unsupervised representation learning with deep convolutional generative adversarial networks." arXiv preprint arXiv:1511.06434 (2015)</a>.*

# %% [markdown]
# The goal of this part is to enhance your results achieved in the part one with DCGAN. Feel free to reuse your code, improve architecture or training scheme, etc.

# %%
class CFG:
    batch_size = 128
    num_epochs = 300
    workers = 4
    seed = 2021
    image_size = 64
    download = True
    dataroot = "data"
    nc = 3  ## number of chanels
    ngf = 64  # Size of feature maps in generator
    nz = 100  # latent random input vector
    ndf = 64  # Size of feature maps in discriminator
    lr = 0.0002
    device = "cuda" if torch.cuda.is_available() else "cpu"
    sample_dir = "./images/"


if not os.path.exists(CFG.sample_dir):
    os.makedirs(CFG.sample_dir)

cifar_dataset = CIFAR10(
    root=CFG.dataroot,
    download=CFG.download,
    transform=transforms.Compose(
        [
            transforms.Resize([CFG.image_size, CFG.image_size]),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
        ]
    ),
)
# Out:
# 100.0%

# %%
img, label = cifar_dataset[0]
print("Label: ", label)
plt.hist(img[:, 5:15, 5:15].flatten(), bins=15)
# Out:
# Label:  6
# (array([ 3.,  6., 52., 36.,  6.,  4., 12., 40., 40.,  7.,  2.,  6., 22.,
#         32., 32.]),
#  array([-0.87450981, -0.81124187, -0.74797386, -0.68470585, -0.62143791,
#         -0.55816996, -0.49490196, -0.43163398, -0.368366  , -0.30509806,
#         -0.24183005, -0.17856205, -0.1152941 , -0.05202615,  0.01124185,
#          0.07450986]),
#  <BarContainer object of 15 artists>)

# %%
# unnormalization image from range (-1)-1 to range 0-1 to display it
def denorm(img):
    return (img + 1) / 2

# show image sample with matplotlib
img, label = cifar_dataset[0]
plt.figure(figsize=(4, 4))
plt.imshow(denorm(img).permute(1, 2, 0))
plt.title(f'Label: {label}')
plt.axis('off')
plt.show()

# %%
# create the dataloader
data_loader = torch.utils.data.DataLoader(
    dataset=cifar_dataset,
    batch_size=CFG.batch_size,
    shuffle=True,
    num_workers=CFG.workers,
    drop_last=True
)

# %% [markdown]
# ### DCGAN implementation

# %%
class DCGenerator(nn.Module):
    def __init__(self, nc, nz, ngf):
        # ConvTranspose2d - BatchNorm - Relu -ConvTranspose2d - BatchNorm - Relu -ConvTranspose2d - BatchNorm - Relu
        # ConvTranspose2d - BatchNorm - Relu - ConvTranspose2d - Tanh
        super(DCGenerator, self).__init__()
        self.main = nn.Sequential(
            # input is Z, going into a convolution
            # nz x 1 x 1 -> ngf*8 x 4 x 4
            nn.ConvTranspose2d(nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            # ngf*8 x 4 x 4 -> ngf*4 x 8 x 8
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            # ngf*4 x 8 x 8 -> ngf*2 x 16 x 16
            nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            # ngf*2 x 16 x 16 -> ngf x 32 x 32
            nn.ConvTranspose2d(ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            # ngf x 32 x 32 -> nc x 64 x 64
            nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, x):
        return self.main(x)


class DCDiscriminator(nn.Module):
    def __init__(self, nc, ndf):
        # conv2d - leaky - conv2d - batchnorm - leaky - conv2d - batchnorm - leaky - conv - batchnorm - leaky - conv2d
        super(DCDiscriminator, self).__init__()
        self.main = nn.Sequential(
            # input is nc x 64 x 64 -> ndf x 32 x 32
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # ndf x 32 x 32 -> ndf*2 x 16 x 16
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # ndf*2 x 16 x 16 -> ndf*4 x 8 x 8
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # ndf*4 x 8 x 8 -> ndf*8 x 4 x 4
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            # ndf*8 x 4 x 4 -> 1 x 1 x 1
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.main(x)

# %%
# create new Generator model
DCG = DCGenerator(CFG.nc, CFG.nz, CFG.ngf)

# create new Discriminator model
DCD = DCDiscriminator(CFG.nc, CFG.ndf)

# Apply weight initialization
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

DCG.apply(weights_init)
DCD.apply(weights_init)

print("Generator:", DCG)
print("\nDiscriminator:", DCD)
# Out:
# Generator: DCGenerator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )
#
# Discriminator: DCDiscriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )

# %%
# show the output of model (need to reshape input to nz x 1 x 1)
y = DCG(torch.randn(2, CFG.nz, 1, 1))
print("Generator output shape:", y.shape)
# Out:
# Generator output shape: torch.Size([2, 3, 64, 64])

# %%
# define the criterion is nn.BCELoss()
criterion = nn.BCELoss()

# Define the optimizer for generator and discriminator
dc_d_optimizer = torch.optim.Adam(DCD.parameters(), lr=CFG.lr, betas=(0.5, 0.999))
dc_g_optimizer = torch.optim.Adam(DCG.parameters(), lr=CFG.lr, betas=(0.5, 0.999))

# %%
# training functions for DCGAN
def dc_reset_grad():
    dc_d_optimizer.zero_grad()
    dc_g_optimizer.zero_grad()


def train_dc_discriminator(DCD_model, DCG_model, images):
    batch_size = images.size(0)
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1, 1, 1).to(CFG.device)
    fake_labels = torch.zeros(batch_size, 1, 1, 1).to(CFG.device)

    # Loss for real images
    outputs = DCD_model(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, CFG.nz, 1, 1).to(CFG.device)
    fake_images = DCG_model(z)
    outputs = DCD_model(fake_images.detach())
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Sum losses
    d_loss = d_loss_real + d_loss_fake

    # Reset gradients
    dc_reset_grad()

    # Compute gradients
    d_loss.backward()

    # Adjust the parameters using backprop
    dc_d_optimizer.step()

    return d_loss, real_score, fake_score


def train_dc_generator(DCG_model, DCD_model, batch_size):
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, CFG.nz, 1, 1).to(CFG.device)
    fake_images = DCG_model(z)
    labels = torch.ones(batch_size, 1, 1, 1).to(CFG.device)
    
    # calculate the generator loss
    outputs = DCD_model(fake_images)
    g_loss = criterion(outputs, labels)

    # Reset gradients
    dc_reset_grad()

    # Backprop and optimize
    g_loss.backward()
    dc_g_optimizer.step()

    return g_loss, fake_images

# %% [markdown]
# ### Start the training proccess

# %%
def save_fake_images_cifar(DCG_model, index):
    sample_vectors = torch.randn(CFG.batch_size, CFG.nz, 1, 1).to(CFG.device)
    fake_images = DCG_model(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 3, 64, 64)
    fake_fname = "fake_images-{0:0=4d}.png".format(index)
    print("Saving", fake_fname)
    save_image(
        denorm(fake_images), os.path.join(CFG.sample_dir, fake_fname), nrow=10
    )

# %%
# %%time
device = CFG.device
num_epochs = CFG.num_epochs
batch_size = CFG.batch_size

total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []
DCG.to(device)
DCD.to(device)

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch (keep images in their original shape for convolutions)
        images = images.to(device)

        # Train the discriminator
        d_loss, real_score, fake_score = train_dc_discriminator(DCD, DCG, images)

        # Train the generator
        g_loss, fake_images = train_dc_generator(DCG, DCD, batch_size)

        # Inspect the losses
        if (i + 1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print(
                "Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}".format(
                    epoch,
                    num_epochs,
                    i + 1,
                    total_step,
                    d_loss.item(),
                    g_loss.item(),
                    real_score.mean().item(),
                    fake_score.mean().item(),
                )
            )
    # Sample and save images
    save_fake_images_cifar(DCG, epoch + 1)
# Out:
# Epoch [0/300], Step [200/390], d_loss: 0.9637, g_loss: 2.7615, D(x): 0.49, D(G(z)): 0.01
# Saving fake_images-0001.png

# %%
# show your results!
from IPython.display import Image as IPImage

# Show a sample generated image
IPImage(os.path.join(CFG.sample_dir, "fake_images-0100.png"))

# %%
# show the discriminator loss and generator loss for DCGAN
plt.figure(figsize=(10, 5))
plt.plot(d_losses, "-", label='Discriminator')
plt.plot(g_losses, "-", label='Generator')
plt.xlabel("Step (x200)")
plt.ylabel("Loss")
plt.legend()
plt.title("DCGAN Losses")
plt.show()

# %%
# plot the accuracy of discriminator for DCGAN
plt.figure(figsize=(10, 5))
plt.plot(real_scores, "-", label='Real Score')
plt.plot(fake_scores, "-", label='Fake Score')
plt.xlabel("Step (x200)")
plt.ylabel("Score")
plt.legend()
plt.title("DCGAN Discriminator Scores")
plt.show()
